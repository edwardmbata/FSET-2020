# %%
import pandas as pd
import geopandas as geo

# %%
MontSHP = geo.read_file("Montopolis/Montopolis.shp")

# %%
MontSHP.head()
# Out:
#        PID_10  PREVIOUS_L  PREVIOUS_G  CURRENT_LA  CURRENT_GE SOURCE NOTES  \
# 0  0308140614         100         100         100         100   None  None
# 1  0308140616         100         100         100         100   None  None
# 2  0308140612         100         100         100         100   None  None
# 3  0308140606         100         100         100         100   None  None
# 4  0308140605         100         100         100         100   None  None
#
#    UNITS  FREQUENCY FIRST_prop  ... Cnt_GEO_ID  UNITSPERAC HHSIZE  POP_2014  \
# 0      1          1          R  ...          1    6.541390    2.8  2.600000
# 1      1          1          R  ...          1    6.901662    2.8  2.600000
# 2      1          1          R  ...          1    4.393265    3.0  2.785714
# 3      1          1          R  ...          1    4.642924    3.0  2.785714
# 4      1          1          R  ...          1    4.452386    3.0  2.785714
#
# ...

# %%
MontSHP.plot()
# Out:
# <AxesSubplot:>
